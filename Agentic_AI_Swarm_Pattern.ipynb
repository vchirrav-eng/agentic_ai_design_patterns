# %%
# !pip install google-genai pydantic

# %%
import os
os.environ['GEMINI_API_KEY'] = 'MY_API_KEY'

# %%
import os
from google import genai
from pydantic import BaseModel, Field
from enum import Enum

# Initialize the Google GenAI client (uses GEMINI_API_KEY from environment)
client = genai.Client()
MODEL_ID = 'gemini-2.5-flash'

# --- 1. Define the Swarm Network & Structured Outputs ---

class SwarmRole(str, Enum):
    MARKET = "Market Researcher"
    ENGINEER = "Engineering Agent"
    FINANCE = "Financial Modeling Agent"
    FINISH = "Consensus Reached (Finish)"

class DispatcherDecision(BaseModel):
    first_agent: SwarmRole = Field(description="The agent best suited to start the task.")
    reasoning: str = Field(description="Why this agent was chosen to start.")

class SwarmHandoff(BaseModel):
    contribution: str = Field(description="Your detailed analysis, proposal, or critique based on the current debate.")
    next_agent: SwarmRole = Field(description="The next agent to hand off to, or FINISH if a final design specification balancing all requirements has been achieved.")

# --- 2. Define the Agent Definitions ---

AGENT_PROMPTS = {
    SwarmRole.MARKET: "You represent consumer demands. Focus on what features users want and market trends.",
    SwarmRole.ENGINEER: "You represent technical feasibility. Focus on building the product, materials, and technical constraints.",
    SwarmRole.FINANCE: "You represent the budget. Focus on manufacturing costs, profit margins, and financial viability."
}

def swarm_node_agent(role: SwarmRole, conversation_history: str) -> SwarmHandoff:
    """A generic node function representing any agent in the swarm."""
    print(f"      -> [{role.value}] Analyzing and drafting contribution...")

    prompt = f"""You are the {role.value}.
    Your Directive: {AGENT_PROMPTS.get(role, "")}

    Current Swarm Debate & History:
    {conversation_history}

    Task:
    1. Read the history. Add your expert contribution, critique proposals from other agents, or build upon their ideas.
    2. Determine who needs to speak next (handoff).
    3. If the team has collectively converged on a final, balanced design specification, hand off to 'FINISH'.
    """

    response = client.models.generate_content(
        model=MODEL_ID,
        contents=prompt,
        config={
            'response_mime_type': 'application/json',
            'response_schema': SwarmHandoff,
            'temperature': 0.4, # Slightly higher temperature for creative debate
        },
    )
    return response.parsed

# --- 3. Define the Dispatcher Agent ---

def dispatcher_agent(user_request: str) -> SwarmRole:
    """Interprets the user request and determines which agent begins."""
    print("-> [Dispatcher] Interpreting request to find the best starting agent...")

    prompt = f"""Determine which specialized agent should begin this product design task.
    User Request: {user_request}"""

    response = client.models.generate_content(
        model=MODEL_ID,
        contents=prompt,
        config={
            'response_mime_type': 'application/json',
            'response_schema': DispatcherDecision,
        },
    )
    decision = response.parsed
    print(f"-> [Dispatcher] Routing to {decision.first_agent.value}. Reason: {decision.reasoning}\n")
    return decision.first_agent

# --- 4. The Swarm Environment (Execution Loop) ---

def swarm_workflow(user_request: str, max_iterations: int = 5) -> str:
    """Manages the swarm environment, shared memory, and explicit exit conditions."""
    print(f"Starting Swarm Workflow for: '{user_request}'\n")

    # Initialize the shared context/memory
    shared_history = f"User Request: {user_request}\n\n"

    # The dispatcher routes the query to an agent in the swarm to begin
    current_agent_role = dispatcher_agent(user_request)

    iteration = 1

    # Explicit Exit Condition: Max iterations to prevent unproductive loops
    while iteration <= max_iterations:
        print(f"--- Swarm Iteration {iteration} | Active Agent: {current_agent_role.value} ---")

        # Agent executes its task based on the shared history
        handoff_data = swarm_node_agent(current_agent_role, shared_history)

        print(f"   [Contribution]: {handoff_data.contribution[:100]}...\n")

        # Append the agent's contribution to the shared history for others to see
        shared_history += f"--- {current_agent_role.value} ---\n{handoff_data.contribution}\n\n"

        # Explicit Exit Condition: Consensus reached
        if handoff_data.next_agent == SwarmRole.FINISH:
            print("-> ✅ Swarm consensus reached! Returning final response.\n")
            return shared_history

        # Handoff: The agent determines who is better suited to handle the next step
        print(f"   [Handoff] -> Routing next to: {handoff_data.next_agent.value}\n")
        current_agent_role = handoff_data.next_agent
        iteration += 1

    print("-> ⚠️ Swarm did not converge. Max iterations reached. Returning current state.\n")
    return shared_history

# --- Execution ---
if __name__ == "__main__":
    # Ambiguous, highly complex problem
    task = "Design a smart, heated winter jacket that charges via solar panels."

    # Trigger the swarm
    final_debate_log = swarm_workflow(task)

    print("=== Final Swarm Consensus Log ===")
    print(final_debate_log)
# Out:
# Starting Swarm Workflow for: 'Design a smart, heated winter jacket that charges via solar panels.'
#
# -> [Dispatcher] Interpreting request to find the best starting agent...
# -> [Dispatcher] Routing to Market Researcher. Reason: To design a new product like a smart, heated winter jacket with solar charging, it is crucial to first understand the market demand, target audience, competitive landscape, and potential feature set. The Market Researcher can identify existing gaps, validate the product concept, and determine the most desired features before any engineering or financial modeling begins.
#
# --- Swarm Iteration 1 | Active Agent: Market Researcher ---
#       -> [Market Researcher] Analyzing and drafting contribution...
#    [Contribution]: The concept of a smart, heated winter jacket with solar charging is highly appealing to consumers, e...
#
#    [Handoff] -> Routing next to: Engineering Agent
#
# --- Swarm Iteration 2 | Active Agent: Engineering Agent ---
#       -> [Engineering Agent] Analyzing and drafting contribution...
#    [Contribution]: The market appeal for a smart, heated, solar-charging jacket is clear. From an engineering standpoin...
#
#    [Handoff] -> Routing next to: Financial Modeling Agent
#
# --- Swarm Iteration 3 | Active Agent: Financial Modeling Agent ---
#       -> [Financial Modeling Agent] Analyzing and drafting contribution...
#    [Contribution]: The market's desire for a smart, heated, solar-charging jacket is clear, and the Engineering Agent h...
#
#    [Handoff] -> Routing next to: Engineering Agent
#
# --- Swarm Iteration 4 | Active Agent: Engineering Agent ---
#       -> [Engineering Agent] Analyzing and drafting contribution...
#    [Contribution]: I agree with the Financial Modeling Agent's astute assessment regarding the significant cost implica...
#
#    [Handoff] -> Routing next to: Financial Modeling Agent
#
# --- Swarm Iteration 5 | Active Agent: Financial Modeling Agent ---
#       -> [Financial Modeling Agent] Analyzing and drafting contribution...
#    [Contribution]: The Engineering Agent's proposed compromise for washability—a modular, easily removable battery and ...
#
#    [Handoff] -> Routing next to: Market Researcher
#
# -> ⚠️ Swarm did not converge. Max iterations reached. Returning current state.
#
# === Final Swarm Consensus Log ===
# User Request: Design a smart, heated winter jacket that charges via solar panels.
#
# --- Market Researcher ---
# The concept of a smart, heated winter jacket with solar charging is highly appealing to consumers, especially those in cold climates or outdoor enthusiasts. From a market perspective, key features beyond basic heating and solar charging will drive adoption. Consumers will demand precise temperature control, ideally with zoned heating options (e.g., core, hands, back) and an intuitive interface, possibly via a smartphone app. Battery life is crucial; it must last for extended periods, and solar charging needs to be efficient, but a backup USB-C charging port is non-negotiable for cloudy days or indoor charging. The jacket must also be lightweight, comfortable, and stylish, avoiding the bulky appearance often associated with heated apparel. Weather resistance (waterproof and windproof) and breathability are essential for a winter jacket. Durability, ease of cleaning (machine washable), and safety features (overheat protection) are also high priorities. Finally, discreet integration of solar panels that don't compromise aesthetics or flexibility will be a significant differentiator.
#
# --- Engineering Agent ---
# The market appeal for a smart, heated, solar-charging jacket is clear. From an engineering standpoint, several aspects are feasible, but others present significant challenges and require careful consideration of trade-offs.
#
# **Heating System:** Precise temperature control, zoned heating, and smartphone app integration are all technically achievable using flexible heating elements (e.g., carbon fiber, graphene), thermistors for feedback, and a Bluetooth module. Overheat protection is a critical safety feature that can be implemented with redundant sensors and control logic.
#
# **Power System (Battery & Charging):**
# *   **Battery:** Achieving 'extended periods' of heating will require a high-capacity, lightweight battery. Given the cold environment, selecting a battery chemistry that performs well in low temperatures (e.g., specific Li-ion or Li-polymer formulations) is crucial. Battery placement must consider weight distribution and user comfort.
# *   **Solar Charging:** This is the most challenging aspect. While flexible solar panels can be discreetly integrated, their power output, especially from the limited surface area on a jacket and in typical winter conditions (lower sun angle, cloud cover), will likely be insufficient for 'efficient' primary charging of a battery large enough to power heating for extended periods. It's more realistic to consider solar as a supplementary charger, extending battery life rather than fully recharging it. We need to set realistic expectations for solar contribution. A robust, waterproofed USB-C port for primary charging is indeed non-negotiable.
#
# **Materials & Construction:**
# *   **Lightweight, Comfortable, Stylish:** This requires advanced insulation materials and careful design. Integrating heating elements and wiring without adding bulk or stiffness is key.
# *   **Weather Resistance & Breathability:** Standard high-performance outdoor fabrics (e.g., waterproof/breathable membranes) can be used. The challenge lies in integrating electronics while maintaining the integrity of these layers and ensuring all connections are fully sealed.
# *   **Durability & Machine Washability:** This is a major engineering hurdle. All electronic components – heating elements, wiring, battery, control unit, solar panels, and USB-C port – must be fully waterproofed and robust enough to withstand repeated machine washing cycles. This likely necessitates fully encapsulated modules or a design where electronics are easily removable, adding complexity and potential points of failure if not meticulously engineered.
#
# **Discreet Integration:** Achieving discreet solar panel integration while maximizing surface area for power generation is a direct trade-off. We need to balance aesthetics with practical solar energy harvesting. The overall design must ensure flexibility and comfort are not compromised by integrated components.
#
# In summary, while the vision is exciting, the practical implementation of truly 'efficient' solar charging for primary heating power and full machine washability for integrated electronics presents significant engineering challenges that will impact cost and design complexity.
#
# --- Financial Modeling Agent ---
# The market's desire for a smart, heated, solar-charging jacket is clear, and the Engineering Agent has outlined the technical feasibility of many features. However, from a financial modeling perspective, several engineering challenges translate directly into significant cost drivers that could severely impact profit margins and overall financial viability. The two most critical areas of concern are 'efficient primary solar charging' and 'full machine washability' for integrated electronics.The Engineering Agent correctly identifies that solar charging will likely be supplementary, not primary. Investing heavily in R&D and manufacturing for 'efficient' solar panels that provide marginal primary charging power, especially given limited surface area and winter conditions, presents a poor return on investment. The cost-benefit analysis here suggests that marketing it as 'solar-assisted' or 'solar-extended battery life' with a robust USB-C primary charging port is a more financially sound approach, managing both consumer expectations and manufacturing costs.The 'full machine washability' requirement is a major financial red flag. The engineering hurdle of fully waterproofing and robustly encapsulating all electronic components (heating elements, battery, control unit, solar panels, wiring, USB-C port) to withstand repeated machine washing cycles will incur extremely high R&D costs, complex manufacturing processes, rigorous quality control, and a high risk of product failures and associated warranty claims. This feature alone could make the product prohibitively expensive to produce at a viable profit margin. We need to critically assess if the market is willing to pay the premium required for this feature, or if a compromise (e.g., hand wash only with electronics removed, or spot cleaning) would be more acceptable for a lower, more competitive price point.Furthermore, the use of high-capacity, cold-weather-performing batteries, advanced lightweight/insulation materials, zoned heating, and smartphone app integration all add to the bill of materials and software development costs. While these features enhance market appeal, their cumulative cost must be carefully balanced against a realistic target selling price. We need to ensure that the proposed feature set doesn't price the product out of its target market or leave insufficient room for profit. My primary concern is that the current engineering approach to certain premium features, particularly washability, will lead to unsustainable manufacturing costs and potential warranty liabilities.
#
# --- Engineering Agent ---
# I agree with the Financial Modeling Agent's astute assessment regarding the significant cost implications of certain features, particularly 'efficient primary solar charging' and 'full machine washability.' My previous analysis already highlighted these as major engineering hurdles, and the financial perspective reinforces the need for realistic expectations and potential design compromises.Regarding Solar Charging: I concur completely that positioning solar as a 'supplementary' or 'solar-assisted' charging mechanism, extending battery life rather than providing primary power, is the most technically feasible and financially sound approach. This avoids costly R&D into high-efficiency, large-surface-area panels that would struggle in real-world winter conditions and compromise aesthetics. We can engineer for effective trickle charging to extend usage time, with the USB-C port as the primary charging method.Regarding Machine Washability: This remains the single biggest engineering and financial challenge. While full encapsulation of all electronics to withstand repeated machine washing is technically *possible*, the Financial Modeling Agent is absolutely correct that it would incur exorbitant R&D, manufacturing complexity, rigorous testing, and significant warranty risks. This would push the product into an extremely high price bracket, potentially beyond market acceptance.Therefore, from an engineering standpoint, I propose focusing on a design that allows for the jacket itself to be machine washable, but with easily removable electronic components. This would involve:1.  Modular Battery and Control Unit: Designing the battery pack and main control unit (including Bluetooth module) as a single, easily detachable module that can be unplugged and removed from a dedicated, sealed pocket before washing.2.  Robust, Water-Resistant Connectors: The connectors for heating elements and sensors would need to be highly durable and water-resistant when connected, but not necessarily fully submersible for washing. The heating elements themselves (e.g., carbon fiber or graphene) can be integrated into the fabric and designed to withstand washing *provided they are disconnected from power*.3.  Sealed Solar Panel Integration: The solar panels, being external, would need to be fully sealed and integrated into the fabric to withstand washing, but their connection to the removable battery module would also be part of the detachable system.This approach significantly reduces the engineering complexity and cost associated with fully waterproofing and encapsulating the most sensitive and expensive electronic components. It offers a practical compromise: the user can machine wash the jacket fabric after removing the core electronics, which aligns with a more financially viable product.The costs associated with high-capacity, cold-performing batteries, advanced materials, zoned heating, and app integration are indeed additive, but these are more straightforward engineering challenges compared to the washability issue. We can optimize these within budget constraints once the core washability strategy is defined.Given these proposed engineering compromises, especially on washability, the Financial Modeling Agent needs to re-evaluate the cost implications and potential pricing strategies. It would be beneficial to model the cost savings and assess the market's willingness to accept a "removable electronics for washing" feature versus a fully integrated, but much more expensive, solution.
#
# --- Financial Modeling Agent ---
# The Engineering Agent's proposed compromise for washability—a modular, easily removable battery and control unit, with integrated heating elements designed to withstand washing when disconnected—is a critical and highly welcome development from a financial perspective. This approach directly addresses my primary concern regarding the exorbitant R&D, manufacturing complexity, and warranty risks associated with fully encapsulating all electronics for machine washability. This modular design significantly reduces the bill of materials for specialized waterproofing, streamlines assembly processes, and drastically lowers the potential for costly product failures and returns. It transforms what was a major financial red flag into a manageable engineering challenge with a much more favorable cost-benefit profile. The consensus on positioning solar charging as supplementary rather than primary also aligns perfectly with cost-effective manufacturing and realistic consumer expectations. While the costs associated with high-capacity, cold-performing batteries, advanced lightweight materials, zoned heating, and app integration remain, these are now within a more financially viable framework, especially with the washability hurdle largely mitigated. Before I can proceed with a detailed financial model that incorporates these revised cost structures and projects profit margins, it is crucial to understand the market's perception and acceptance of the 'removable electronics for washing' compromise. This feature, while financially sound, represents a deviation from the ideal 'fully machine washable' initially desired by the market. The Market Researcher needs to assess if consumers will find this an acceptable trade-off for a potentially more affordable and reliable product, or if it significantly diminishes market appeal. Their feedback will directly influence our sales volume projections and target pricing strategies, which are essential inputs for my financial modeling.
